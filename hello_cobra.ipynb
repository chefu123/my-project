# %% [markdown]
# 不要跑 `%pip install`。Notebook 内核解析不了 `pypi.org`，而且默认内核是隔离的，看不到 `pip --user` 装的包。
#
# 1. 右上角内核选 **`.venv`**（或 `Python 3.12` / `/usr/bin/python3`）
# 2. **Restart Kernel**
# 3. 只跑下面的 import

# %%
import sys
print("python:", sys.executable)

import cobra
print("cobra:", cobra.__version__, cobra.__file__)

model = cobra.Model("demo")
print("model:", model.id, "ok")
