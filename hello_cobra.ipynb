# %% [markdown]
# Notebook 在远程服务器上。不要 `%pip`（内核解析不了 pypi.org）。
#
# 先跑下一格，把 `sys.executable` 拿到服务器终端，用那个 Python 安装 cobra。
# 装完后 **Restart Kernel**，再跑最后一格。

# %%
import sys
print(sys.executable)
print(sys.version)

# %% [markdown]
# 下一格是 **bash**，必须在 SSH 终端跑，或在 notebook 里加 `!`。不要当 Python 代码跑。
#
# ```bash
# /opt/jhub/venv/bin/python3 -m pip install cobra==0.32.1 -i https://pypi.tuna.tsinghua.edu.cn/simple
# ```
#
# notebook 里写成：
#
# ```
# !/opt/jhub/venv/bin/python3 -m pip install cobra==0.32.1 -i https://pypi.tuna.tsinghua.edu.cn/simple
# ```

# %%
import cobra
print("cobra:", cobra.__version__, cobra.__file__)

model = cobra.Model("demo")
print("model:", model.id, "ok")
